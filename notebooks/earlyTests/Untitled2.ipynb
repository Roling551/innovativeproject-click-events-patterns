# %%
from bokeh.models.widgets import RadioGroup
from bokeh.models.widgets import TextInput
from bokeh.io import output_file, show
from bokeh.io import output_notebook

def my_text_input_handler(attr, old, new):
    print("Previous label: " + old)
    print("Updated label: " + new)

text_input = TextInput(value="default", title="Label:")
text_input.on_change("value", my_text_input_handler)

show(text_input)
output_notebook()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c987c583-9f5d-4f7a-b6f6-21bbe2b2ab85"></div>
# </div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0e252218-857d-4e11-a04d-2de4b8d6791d">Loading BokehJS ...</span>
#     </div>

# %%
import ipywidgets as wg

#c_slide = wg.FloatSlider(value=1.0, min=0,max=3.0,step = 0.1)
display(c_slide)
# Out:
# FloatSlider(value=1.0, max=3.0)

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
p = figure(x_range=(0,9), y_range=(0,9),toolbar_location=None)
p.vbar(x=1, top=1, width=0.9)
show(p)
output_notebook()
import ipywidgets as wg

c_slide = wg.FloatSlider(value=1.0, min=0,max=3.0,step = 0.1)
display(c_slide)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4df77943-9b52-4c5e-ab0b-5701b95f1a80"></div>
# </div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="34e33f00-16d5-4386-95ca-ec2cf5e7ee01">Loading BokehJS ...</span>
#     </div>
# FloatSlider(value=1.0, max=3.0)

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook, push_notebook
import ipywidgets as wg
output_notebook()
def my_graph(integer):
    p = figure(x_range=(0,9), y_range=(0,9),toolbar_location=None)
    p.vbar(x=integer, top=1, width=0.9)
    show(p)


c_slide = wg.FloatSlider(value=1.0, min=0,max=3.0,step = 0.1)
wg.interact(my_graph, integer = c_slide )
#display(c_slide)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="261070cb-6866-4983-a8a1-23dd80aa14df">Loading BokehJS ...</span>
#     </div>
# interactive(children=(FloatSlider(value=1.0, description='integer', max=3.0), Output()), _dom_classes=('widget-interact',))
# <function __main__.my_graph>
